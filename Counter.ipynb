# %%
import pandas as pd

# %%
begin = pd.read_csv("data/session_seperated_background.txt", header = None)

# %%
grouped = begin.groupby([0]).size().sort_values(ascending=False)
grouped = grouped.reset_index(name="counts")
grouped
# Out:
#                                                           0   counts
# 0                                                       com  2828547
# 1                                                       org   155613
# 2                                                    google   149809
# 3                                                       net    92066
# 4                                                 yahoo com    84668
# 5                                                      ebay    81610
# 6                                               myspace com    69650
# 7                                                     yahoo    66425
# 8                                                google com    65794
# 9                                                       gov    65650
# 10                                                   lyrics    63152
# 11                                                      edu    62504
# 12                                                 mapquest    49056
# ...

# %%
top100k = grouped.iloc[range(100000),:]
top100k['words'] = top100k[0].str.split().str.len()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
top100k[top100k['words']==2].nlargest(10, 'counts')
# Out:
#               0  counts  words
# 4     yahoo com   84668      2
# 6   myspace com   69650      2
# 8    google com   65794      2
# 27     ebay com   26165      2
# 36     for sale   21881      2
# 54  hotmail com   16767      2
# 59     new york   16299      2
# 70    map quest   14995      2
# 72   of america   14728      2
# 83     my space   13187      2

# %%
top100k[(top100k['words']==3) & ~(top100k[0].str.startswith('www'))].nlargest(20, 'counts')
# Out:
#                               0  counts  words
# 94              bank of america   12479      3
# 134                my space com    9707      3
# 254          disney channel com    6072      3
# 303        mycl cravelyrics com    5166      3
# 371        federal credit union    4275      3
# 518              ww myspace com    3290      3
# 548               new york city    3184      3
# 562             kelly blue book    3120      3
# 603                  or no deal    2980      3
# 672              ask jeeves com    2736      3
# 679                 in new york    2722      3
# 715   department of corrections    2576      3
# 767         chamber of commerce    2460      3
# 794             bath and beyond    2394      3
# 807              homes for sale    2361      3
# 951               evo qksrv net    2045      3
# 1053              in new jersey    1897      3
# 1075           barnes and noble    1876      3
# 1146         web addresses here    1789      3
# ...

# %%
top100k[top100k['words'] == top100k['words'].max()]
# Out:
#                                                        0  counts  words
# 45405  http version 1 0 a schemas microsoft com excha...      50     94

# %%
top100k[top100k[0]==""]
# Out:
# Empty DataFrame
# Columns: [0, counts, words]
# Index: []

# %%
top100k[top100k['words']==3].nlargest(10, 'counts')
# Out:
#                         0  counts  words
# 30          www yahoo com   24985      3
# 33         www google com   23472      3
# 46        www myspace com   17922      3
# 94        bank of america   12479      3
# 134          my space com    9707      3
# 200          www ebay com    7100      3
# 254    disney channel com    6072      3
# 287       www hotmail com    5490      3
# 303  mycl cravelyrics com    5166      3
# 371  federal credit union    4275      3

# %%
grouped.to_csv("data/Freq_background.csv")

# %%
grouped[grouped[0] == "department of corrections"]
# Out:
#                              0  counts
# 715  department of corrections    2576
